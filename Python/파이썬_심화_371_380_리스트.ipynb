# %% [markdown]
# # 파이썬 심화 문제집 - 리스트

# %% [markdown]
# ## 리스트 심화 (371 ~ 380)

# %% [markdown]
# ### 371 리스트 중간값(median)

# %% [markdown]
# 정렬 없이 직접 중간값을 구하세요.
# ```python
# nums=[7,1,5,3,9]
# # 결과: 5
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# nums=[7,1,5,3,9]
# sorted_n=sorted(nums)
# mid=len(sorted_n)//2
# print(sorted_n[mid] if len(sorted_n)%2 else (sorted_n[mid-1]+sorted_n[mid])/2)
# </pre>
# </details>

# %%
nums=[7,1,5,3,9]
sorted_n=sorted(nums)
mid=len(sorted_n)//2
print(sorted_n[mid] if len(sorted_n)%2 else (sorted_n[mid-1]+sorted_n[mid])/2)
# Out:
# 5

# %% [markdown]
# ### 372 리스트 상위 n개 추출

# %% [markdown]
# 리스트에서 가장 큰 n개 값을 추출하세요.
# ```python
# nums=[3,1,4,1,5,9,2,6,5,3]; n=3
# # 결과: [9,6,5]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# import heapq
# nums=[3,1,4,1,5,9,2,6,5,3]; n=3
# print(heapq.nlargest(n,nums))
# </pre>
# </details>

# %%
nums=[3,1,4,1,5,9,2,6,5,3]; n=3

sorted_n=sorted(nums,reverse=True)
print(sorted_n[:n])
# Out:
# [9, 6, 5]

# %% [markdown]
# ### 373 리스트 연속 부분합 최대값

# %% [markdown]
# 연속된 부분 리스트의 합이 최대인 값을 구하세요(카데인 알고리즘).
# ```python
# nums=[-2,1,-3,4,-1,2,1,-5,4]
# # 결과: 6 (4,-1,2,1의 합)
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# nums=[-2,1,-3,4,-1,2,1,-5,4]
# max_sum=cur=nums[0]
# for n in nums[1:]:
#     cur=max(n,cur+n)
#     max_sum=max(max_sum,cur)
# print(max_sum)
# </pre>
# </details>

# %%
nums=[-2,1,-3,4,-1,2,1,-5,4]
max_sum=cur=nums[0]
for n in nums[1:]:
    cur=max(n,cur+n)
    max_sum=max(max_sum,cur)
print(max_sum)
# Out:
# 6

# %% [markdown]
# ### 374 리스트로 행렬 대각선 합

# %% [markdown]
# 정사각 행렬의 주대각선과 부대각선의 합을 구하세요.
# ```python
# matrix=[[1,2,3],[4,5,6],[7,8,9]]
# # 주대각선: 1+5+9=15
# # 부대각선: 3+5+7=15
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# matrix=[[1,2,3],[4,5,6],[7,8,9]]
# n=len(matrix)
# main=sum(matrix[i][i] for i in range(n))
# anti=sum(matrix[i][n-1-i] for i in range(n))
# print('주대각선:',main,'부대각선:',anti)
# </pre>
# </details>

# %%
matrix=[[1,2,3],[4,5,6],[7,8,9]]

n=len(matrix)
main=sum(matrix[i][i] for i in range(n))
sub=sum(matrix[i][n-1-i] for i in range(n))
print('주대각선:',main,'부대각선:',sub)
# Out:
# 주대각선: 15 부대각선: 15

# %% [markdown]
# ### 375 리스트 중복 쌍 찾기

# %% [markdown]
# 리스트에서 합이 특정 값이 되는 모든 쌍을 찾으세요.
# ```python
# nums=[1,5,3,4,2]; target=5
# # 결과: [(1,4),(3,2)]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# nums=[1,5,3,4,2]; target=5
# seen=set(); pairs=[]
# for n in nums:
#     comp=target-n
#     if comp in seen: pairs.append((min(n,comp),max(n,comp)))
#     seen.add(n)
# print(list(set(pairs)))
# </pre>
# </details>

# %%
nums=[1,5,3,4,2]; target=5
seen=set(); pairs=[]
for n in nums:
    comp=target-n
    if comp in seen:
      pairs.append((min(n,comp),max(n,comp)))
    seen.add(n)
print(list(set(pairs)))
# Out:
# [(2, 3), (1, 4)]

# %% [markdown]
# ### 376 리스트 원소 교체

# %% [markdown]
# 리스트에서 특정 값을 모두 새 값으로 교체하세요.
# ```python
# nums=[1,2,3,2,1,2,4]
# # 2를 99로 교체 → [1,99,3,99,1,99,4]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# nums=[1,2,3,2,1,2,4]
# result=[99 if x==2 else x for x in nums]
# print(result)
# </pre>
# </details>

# %%
nums=[1,2,3,2,1,2,4]
result=[99 if x==2 else x for x in nums]
print(result)
# Out:
# [1, 99, 3, 99, 1, 99, 4]

# %% [markdown]
# ### 377 리스트 앞뒤 비교 (팰린드롬)

# %% [markdown]
# 리스트가 팰린드롬(앞뒤가 같은 형태)인지 확인하세요.
# ```python
# a=[1,2,3,2,1] → True
# b=[1,2,3,4,5] → False
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# def is_palindrome(lst):
#     return lst==lst[::-1]
# print(is_palindrome([1,2,3,2,1]))  # True
# print(is_palindrome([1,2,3,4,5]))  # False
# </pre>
# </details>

# %%
a=[1,2,3,2,1]
b=[1,2,3,4,5]
print(a==a[::-1])
print(b==b[::-1])
# Out:
# True
# False

# %% [markdown]
# ### 378 리스트 원소 이동

# %% [markdown]
# 리스트에서 모든 0을 오른쪽으로 이동시키되, 나머지 순서는 유지하세요.
# ```python
# nums=[0,1,0,3,12]
# # 결과: [1,3,12,0,0]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# nums=[0,1,0,3,12]
# non_zero=[x for x in nums if x!=0]
# result=non_zero+[0]*(len(nums)-len(non_zero))
# print(result)
# </pre>
# </details>

# %%
nums=[0,1,0,3,12]
non_zero=[x for x in nums if x!=0]
result=non_zero+[0]*(len(nums)-len(non_zero))
print(result)
# Out:
# [1, 3, 12, 0, 0]

# %% [markdown]
# ### 379 리스트 교차 합산

# %% [markdown]
# 두 리스트를 번갈아가며 합산한 리스트를 만드세요.
# ```python
# a=[1,3,5]; b=[2,4,6]
# # 결과: [1,2,3,4,5,6]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# a=[1,3,5]; b=[2,4,6]
# result=[]
# for x,y in zip(a,b): result+=[x,y]
# if len(a)>len(b): result+=a[len(b):]
# elif len(b)>len(a): result+=b[len(a):]
# print(result)
# </pre>
# </details>

# %%
a=[1,3,5]; b=[2,4,6]
result=[]
for x,y in zip(a,b):
  result+=[x,y]
  print(result)
if len(a)>len(b):
  result+=a[len(b):]
elif len(b)>len(a):
  result+=b[len(a):]
print(result)
# Out:
# [1, 2]
# [1, 2, 3, 4]
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### 380 리스트 원소 좌우 곱

# %% [markdown]
# 각 위치에서 해당 원소를 제외한 나머지의 곱을 구하세요.
# ```python
# nums=[1,2,3,4]
# # 결과: [24,12,8,6] (2*3*4, 1*3*4, 1*2*4, 1*2*3)
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# nums=[1,2,3,4]
# n=len(nums)
# left=[1]*n; right=[1]*n
# for i in range(1,n): left[i]=left[i-1]*nums[i-1]
# for i in range(n-2,-1,-1): right[i]=right[i+1]*nums[i+1]
# print([left[i]*right[i] for i in range(n)])
# </pre>
# </details>

# %%
nums=[1,2,3,4]
n=len(nums)
left=[1]*n
right=[1]*n
for i in range(1,n):
  left[i]=left[i-1]*nums[i-1]
for i in range(n-2,-1,-1):
  right[i]=right[i+1]*nums[i+1]
print([left[i]*right[i] for i in range(n)])
# Out:
# [24, 12, 8, 6]
