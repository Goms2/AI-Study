# %% [markdown]
# # 파이썬 심화 문제집 - 리스트

# %% [markdown]
# ## 리스트 심화 (341 ~ 350)

# %% [markdown]
# ### 341 리스트 컴프리헨션 기초

# %% [markdown]
# 1~20 중 3의 배수인 숫자만 모아 리스트를 만드세요.
# ```
# 결과: [3, 6, 9, 12, 15, 18]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# result=[i for i in range(1,21) if i%3==0]
# print(result)
# </pre>
# </details>

# %%
list=[i for i in range(1,21) if i%3 == 0]
print(list)
# Out:
# [3, 6, 9, 12, 15, 18]

# %% [markdown]
# ### 342 중첩 리스트 컴프리헨션

# %% [markdown]
# 2단부터 9단까지 구구단을 2차원 리스트로 만드세요.
# ```
# [[2,4,6,...18],[3,6,9,...27],...]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# table=[[i*j for j in range(1,10)] for i in range(2,10)]
# for row in table:
#     print(row)
# </pre>
# </details>

# %%
z=[i for i in range(1,10)]
print(z)
print()
table=[[i*j for i in range(1,10)] for j in range(2,10)]
print(table)
print()
for row in table:
    print(row)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
#
# [[2, 4, 6, 8, 10, 12, 14, 16, 18], [3, 6, 9, 12, 15, 18, 21, 24, 27], [4, 8, 12, 16, 20, 24, 28, 32, 36], [5, 10, 15, 20, 25, 30, 35, 40, 45], [6, 12, 18, 24, 30, 36, 42, 48, 54], [7, 14, 21, 28, 35, 42, 49, 56, 63], [8, 16, 24, 32, 40, 48, 56, 64, 72], [9, 18, 27, 36, 45, 54, 63, 72, 81]]
#
# [2, 4, 6, 8, 10, 12, 14, 16, 18]
# [3, 6, 9, 12, 15, 18, 21, 24, 27]
# [4, 8, 12, 16, 20, 24, 28, 32, 36]
# [5, 10, 15, 20, 25, 30, 35, 40, 45]
# [6, 12, 18, 24, 30, 36, 42, 48, 54]
# [7, 14, 21, 28, 35, 42, 49, 56, 63]
# [8, 16, 24, 32, 40, 48, 56, 64, 72]
# [9, 18, 27, 36, 45, 54, 63, 72, 81]

# %% [markdown]
# ### 343 리스트 중복 제거 (순서 유지)

# %% [markdown]
# 리스트에서 중복을 제거하되 순서를 유지하세요.
# ```python
# nums=[3,1,4,1,5,9,2,6,5,3,5]
# # 결과: [3,1,4,5,9,2,6]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# nums=[3,1,4,1,5,9,2,6,5,3,5]
# seen=set()
# result=[x for x in nums if x not in seen and not seen.add(x)]
# print(result)
# </pre>
# </details>

# %%
nums=[3,1,4,1,5,9,2,6,5,3,5]
seen=set()
result=[x for x in nums if x not in seen and not seen.add(x)]
print(result)
# Out:
# [3, 1, 4, 5, 9, 2, 6]

# %% [markdown]
# ### 344 리스트 평탄화 (flatten)

# %% [markdown]
# 2차원 리스트를 1차원으로 만드세요.
# ```python
# matrix=[[1,2,3],[4,5,6],[7,8,9]]
# # 결과: [1,2,3,4,5,6,7,8,9]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# matrix=[[1,2,3],[4,5,6],[7,8,9]]
# flat=[x for row in matrix for x in row]
# print(flat)
# </pre>
# </details>

# %%
matrix=[[1,2,3],[4,5,6],[7,8,9]]
flat=[x for row in matrix for x in row]
print(flat)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# ### 345 리스트 슬라이싱 심화

# %% [markdown]
# 리스트를 n개씩 나누어 2차원 리스트를 만드세요.
# ```python
# data=[1,2,3,4,5,6,7,8,9]
# # n=3 → [[1,2,3],[4,5,6],[7,8,9]]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# data=[1,2,3,4,5,6,7,8,9]
# n=3
# chunks=[data[i:i+n] for i in range(0,len(data),n)]
# print(chunks)
# </pre>
# </details>

# %%
data=[1,2,3,4,5,6,7,8,9]
n=3
data1=[data[i:i+n] for i in range(0,len(data),n)]
print(data1)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# ### 346 리스트 rotate

# %% [markdown]
# 리스트를 k번 오른쪽으로 회전시키세요.
# ```python
# nums=[1,2,3,4,5], k=2
# # 결과: [4,5,1,2,3]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# nums=[1,2,3,4,5]; k=2
# rotated=nums[-k:]+nums[:-k]
# print(rotated)
# </pre>
# </details>

# %%
nums=[1,2,3,4,5]
k=2
rotated=nums[-k:]+nums[:-k]
print(rotated)
# Out:
# [4, 5, 1, 2, 3]

# %% [markdown]
# ### 347 두 리스트 병합 후 정렬

# %% [markdown]
# 두 정렬된 리스트를 하나로 합쳐 정렬하세요.
# ```python
# a=[1,3,5,7]; b=[2,4,6,8]
# # 결과: [1,2,3,4,5,6,7,8]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# a=[1,3,5,7]; b=[2,4,6,8]
# result=sorted(a+b)
# print(result)
# </pre>
# </details>

# %%
a=[1,3,5,7]; b=[2,4,6,8]
c=a+b
result=sorted(c)
print(result)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# ### 348 리스트 누적 합

# %% [markdown]
# 리스트의 누적 합 리스트를 만드세요.
# ```python
# nums=[1,2,3,4,5]
# # 결과: [1,3,6,10,15]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# nums=[1,2,3,4,5]
# from itertools import accumulate
# print(list(accumulate(nums)))
# # 또는:
# result=[]
# s=0
# for n in nums: s+=n; result.append(s)
# print(result)
# </pre>
# </details>

# %%
nums=[1,2,3,4,5]
sum=[]
s=0
for n in nums:
    s+=n
    sum.append(s)
print(sum)
# Out:
# [1, 3, 6, 10, 15]

# %% [markdown]
# ### 349 리스트에서 최빈값 찾기

# %% [markdown]
# 리스트에서 가장 자주 등장하는 값(최빈값)을 찾으세요.
# ```python
# nums=[1,2,3,2,1,2,3,3,3]
# # 결과: 3
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# from collections import Counter
# nums=[1,2,3,2,1,2,3,3,3]
# print(Counter(nums).most_common(1)[0][0])
# </pre>
# </details>

# %%
from collections import Counter
nums=[1,2,3,2,1,2,3,3,3]
print(f"최빈값: {Counter(nums).most_common(1)[0][0]}")
# Out:
# 최빈값: 3

# %% [markdown]
# ### 350 리스트 이동 평균

# %% [markdown]
# 주가 리스트에서 3일 이동 평균 리스트를 구하세요.
# ```python
# prices=[100,105,102,108,110,107,112]
# # [102.33, 105.0, 106.67, 108.33, 109.67]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# prices=[100,105,102,108,110,107,112]
# n=3
# ma=[round(sum(prices[i:i+n])/n,2) for i in range(len(prices)-n+1)]
# print(ma)
# </pre>
# </details>

# %%
prices=[100,105,102,108,110,107,112]
n=3
삼일=[round(sum(prices[i:i+n])/n,2) for i in range(len(prices)-n+1)]
print(삼일)
# Out:
# [102.33, 105.0, 106.67, 108.33, 109.67]
