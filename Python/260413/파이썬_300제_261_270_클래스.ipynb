# %% [markdown]
# # 초보자를 위한 파이썬 300제

# %% [markdown]
# ## 11. 파이썬 클래스 (261 ~ 270) - Stock 클래스

# %% [markdown]
# > 이번 파트는 261번부터 270번까지 Stock 클래스를 단계적으로 완성해 나갑니다.

# %% [markdown]
# ### 261 Stock 클래스 - 빈 클래스 정의

# %% [markdown]
# 주식 종목에 대한 정보를 저장하는 Stock 클래스를 정의해보세요. 클래스는 속성과 메서드를 갖고 있지 않습니다.

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# class Stock:
#     pass
# </pre>
# </details>

# %%
class stock:
  pass

# %% [markdown]
# ### 262 Stock 클래스 - 생성자 (종목명, 종목코드)

# %% [markdown]
# Stock 클래스의 객체가 생성될 때 종목명과 종목코드를 입력받을 수 있도록 생성자를 정의해보세요.
# ```
# 실행 예:
# 삼성 = Stock("삼성전자", "005930")
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# class Stock:
#     def __init__(self, name, code):
#         self.name = name
#         self.code = code
#
# 삼성 = Stock("삼성전자", "005930")
# print(삼성.name)
# print(삼성.code)
# </pre>
# </details>

# %%
class Stock:
  def __init__(self, name, code):
    self.name = name
    self.code = code
삼성 = Stock("삼성전자", "005930")
print(삼성.name)
print(삼성.code)
# Out:
# 삼성전자
# 005930

# %% [markdown]
# ### 263 Stock 클래스 - set_name 메서드

# %% [markdown]
# 객체에 종목명을 입력할 수 있는 set_name 메서드를 추가해보세요.
# ```
# 실행 예:
# a = Stock(None, None)
# a.set_name("삼성전자")
# print(a.name)  # 삼성전자
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# class Stock:
#     def __init__(self, name, code):
#         self.name = name
#         self.code = code
#
#     def set_name(self, name):
#         self.name = name
#
# a = Stock(None, None)
# a.set_name("삼성전자")
# print(a.name)
# </pre>
# </details>

# %%
class Stock:
  def __init__(self, name, code):
    self.name = name
    self.code = code
  def set_name(self, name):
    self.name = name

a = Stock(None, None)
a.set_name("삼성전자")
print(a.name)
# Out:
# 삼성전자

# %% [markdown]
# ### 264 Stock 클래스 - set_code 메서드

# %% [markdown]
# 객체에 종목코드를 입력할 수 있는 set_code 메서드를 추가해보세요.
# ```
# 실행 예:
# a = Stock(None, None)
# a.set_code("005930")
# print(a.code)  # 005930
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# class Stock:
#     def __init__(self, name, code):
#         self.name = name
#         self.code = code
#
#     def set_name(self, name):
#         self.name = name
#
#     def set_code(self, code):
#         self.code = code
#
# a = Stock(None, None)
# a.set_code("005930")
# print(a.code)
# </pre>
# </details>

# %%
class Stock:
  def __init__(self, name, code):
    self.name = name
    self.code = code
  def set_name(self, name):
    self.name = name
  def set_code(self, code):
    self.code = code

a = Stock(None, None)
a.set_code("005930")
print(a.code)  # 005930
# Out:
# 005930

# %% [markdown]
# ### 265 Stock 클래스 - get_name, get_code 메서드

# %% [markdown]
# 종목명과 종목코드를 반환하는 get_name, get_code 메서드를 추가하세요.
# ```
# 실행 예:
# 삼성 = Stock("삼성전자", "005930")
# print(삼성.get_name())  # 삼성전자
# print(삼성.get_code())  # 005930
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# class Stock:
#     def __init__(self, name, code):
#         self.name = name
#         self.code = code
#
#     def set_name(self, name):
#         self.name = name
#
#     def set_code(self, code):
#         self.code = code
#
#     def get_name(self):
#         return self.name
#
#     def get_code(self):
#         return self.code
#
# 삼성 = Stock("삼성전자", "005930")
# print(삼성.get_name())
# print(삼성.get_code())
# </pre>
# </details>

# %%
class Stock:
  def __init__(self, name, code):
    self.name = name
    self.code = code
  def set_name(self, name):
    self.name = name
  def set_code(self, code):
    self.code = code
  def get_name(self):
    return self.name
  def get_code(self):
    return self.code


삼성 = Stock("삼성전자", "005930")
print(삼성.get_name())  # 삼성전자
print(삼성.get_code())  # 005930
# Out:
# 삼성전자
# 005930

# %% [markdown]
# ### 266 Stock 클래스 - 생성자 확장 (PER, PBR, 배당수익률)

# %% [markdown]
# 생성자에서 종목명, 종목코드, PER, PBR, 배당수익률을 입력받을 수 있도록 생성자를 수정하세요. PER, PBR, 배당수익률은 float 타입입니다.

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# class Stock:
#     def __init__(self, name, code, per, pbr, dividend):
#         self.name = name
#         self.code = code
#         self.per = per
#         self.pbr = pbr
#         self.dividend = dividend
#
#     def set_name(self, name): self.name = name
#     def set_code(self, code): self.code = code
#     def get_name(self): return self.name
#     def get_code(self): return self.code
# </pre>
# </details>

# %%
class Stock:
  def __init__(self, name, code, per, pbr, 배당수익률):
    self.name = name
    self.code = code
    self.per = per
    self.pbr = pbr
    self.배당수익률 = 배당수익률

    def set_name(self, name):
      self.name = name
    def set_code(self, code):
      self.code = code
    def get_name(self):
      return self.name
    def get_code(self):
      return self.code

# %% [markdown]
# ### 267 Stock 객체 생성

# %% [markdown]
# 266번에서 정의한 생성자로 다음 정보를 갖는 객체를 생성해보세요.
#
# | 항목 | 정보 |
# | --- | --- |
# | 종목명 | 삼성전자 |
# | 종목코드 | 005930 |
# | PER | 15.79 |
# | PBR | 1.33 |
# | 배당수익률 | 2.83 |

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# 삼성 = Stock("삼성전자", "005930", 15.79, 1.33, 2.83)
# print(삼성.name)
# print(삼성.per)
# print(삼성.dividend)
# </pre>
# </details>

# %%
class Stock:
    def __init__(self, name, code, per, pbr, dividend):
        self.name = name
        self.code = code
        self.per = per
        self.pbr = pbr
        self.dividend = dividend

    def set_name(self, name):
      self.name = name
    def set_code(self, code):
      self.code = code
    def get_name(self):
      return self.name
    def get_code(self):
      return self.code

삼성 = Stock("삼성전자", "005930", 15.79, 1.33, 2.83)
print("항목        정보")
print('-'*20)
print(f"종목명:     {삼성.name}\n종목코드:   {삼성.code}\nPER:        {삼성.per}\nPBR:        {삼성.pbr}\n배당수익률: {삼성.dividend}")
# Out:
# 항목        정보
# --------------------
# 종목명:     삼성전자
# 종목코드:   005930
# PER:        15.79
# PBR:        1.33
# 배당수익률: 2.83

# %% [markdown]
# ### 268 Stock 클래스 - set_per, set_pbr, set_dividend 메서드

# %% [markdown]
# PER, PBR, 배당수익률은 변경될 수 있는 값입니다. 이 값을 변경할 때 사용하는 set_per, set_pbr, set_dividend 메서드를 추가하세요.

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# class Stock:
#     def __init__(self, name, code, per, pbr, dividend):
#         self.name = name
#         self.code = code
#         self.per = per
#         self.pbr = pbr
#         self.dividend = dividend
#
#     def set_name(self, name): self.name = name
#     def set_code(self, code): self.code = code
#     def get_name(self): return self.name
#     def get_code(self): return self.code
#     def set_per(self, per): self.per = per
#     def set_pbr(self, pbr): self.pbr = pbr
#     def set_dividend(self, dividend): self.dividend = dividend
# </pre>
# </details>

# %%
class Stock:
    def __init__(self, name, code, per, pbr, dividend):
        self.name = name
        self.code = code
        self.per = per
        self.pbr = pbr
        self.dividend = dividend

    def set_name(self, name):
      self.name = name
    def set_code(self, code):
      self.code = code
    def get_name(self):
      return self.name
    def get_code(self):
      return self.code
    def set_per(self, per):
      self.per = per
    def set_pbr(self, pbr):
      self.pbr = pbr
    def set_dividend(self, dividend):
      self.dividend = dividend

# %% [markdown]
# ### 269 set_per 메서드로 PER 값 수정

# %% [markdown]
# 267번에서 생성한 삼성전자 객체에 set_per 메서드를 호출하여 per 값을 12.75로 수정해보세요.
# ```
# 실행 예:
# print(삼성.per)  # 12.75
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# 삼성 = Stock("삼성전자", "005930", 15.79, 1.33, 2.83)
# print(삼성.per)   # 15.79
# 삼성.set_per(12.75)
# print(삼성.per)   # 12.75
# </pre>
# </details>

# %%
class Stock:
    def __init__(self, name, code, per, pbr, dividend):
        self.name = name
        self.code = code
        self.per = per
        self.pbr = pbr
        self.dividend = dividend

    def set_per(self, per):
        self.per = per

삼성 = Stock("삼성전자", "005930", 15.79, 1.33, 2.83)
삼성.set_per(12.75)
print(삼성.per)
# Out:
# 12.75

# %% [markdown]
# ### 270 여러 종목 객체를 리스트에 저장 후 순회

# %% [markdown]
# 아래 표를 참조하여 3종목에 대해 객체를 생성하고 파이썬 리스트에 저장하세요. 리스트에 저장된 각 종목에 대해 for 루프로 종목코드와 PER을 출력해보세요.
#
# | 종목명 | 종목코드 | PER | PBR | 배당수익률 |
# | --- | --- | --- | --- | --- |
# | 삼성전자 | 005930 | 15.79 | 1.33 | 2.83 |
# | 현대차 | 005380 | 8.70 | 0.35 | 4.27 |
# | LG전자 | 066570 | 317.34 | 0.69 | 1.37 |
#
# ```
# 실행 예:
# 005930 15.79
# 005380 8.7
# 066570 317.34
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# 종목 = []
# 삼성 = Stock("삼성전자", "005930", 15.79, 1.33, 2.83)
# 현대차 = Stock("현대차", "005380", 8.70, 0.35, 4.27)
# LG전자 = Stock("LG전자", "066570", 317.34, 0.69, 1.37)
#
# 종목.append(삼성)
# 종목.append(현대차)
# 종목.append(LG전자)
#
# for i in 종목:
#     print(i.code, i.per)
# </pre>
# </details>

# %%
from re import S
class Stock:
    def __init__(self, name, code, per, pbr, dividend):
        self.name = name
        self.code = code
        self.per = per
        self.pbr = pbr
        self.dividend = dividend

리스트 = []
Smasung = Stock('삼성전자',	'005930', 15.79,	1.33,	2.83)
Hyundai = Stock('현대차',	'005380',	8.70,	0.35,	4.27)
LG = Stock('LG전자', '066570',	317.34,	0.69,	1.37)

리스트.append(Smasung)
리스트.append(Hyundai)
리스트.append(LG)

print("종목코드 PER")
print('-'*15)

for i in range(3):

  print(f"{리스트[i].code}   {리스트[i].per}")
# Out:
# 종목코드 PER
# ---------------
# 005930   15.79
# 005380   8.7
# 066570   317.34
