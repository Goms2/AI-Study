# %% [markdown]
# # 초보자를 위한 파이썬 300제

# %% [markdown]
# ## 08. 파이썬 반복문 (131 ~ 140)

# %% [markdown]
# ### 131 for문 기초 - 결과 예측

# %% [markdown]
# for문의 실행결과를 예측하라.
# ```python
# 과일 = ["사과", "귤", "수박"]
# for 변수 in 과일:
#     print(변수)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 리스트에 들어있는 값이 한 줄씩 순서대로 출력됩니다.</br>
# <pre>
# # 결과:
# # 사과
# # 귤
# # 수박
# </pre>
# </details>

# %%
과일 = ["사과", "귤", "수박"]
for 변수 in 과일:
    print(변수)
# Out:
# 사과
# 귤
# 수박

# %% [markdown]
# ### 132 for문 반복 횟수 예측

# %% [markdown]
# for문의 실행결과를 예측하라.
# ```python
# 과일 = ["사과", "귤", "수박"]
# for 변수 in 과일:
#     print("#####")
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 리스트에 3개의 데이터가 있으므로 들여쓰기된 코드가 3번 실행됩니다.</br>
# <pre>
# # 결과:
# # #####
# # #####
# # #####
# </pre>
# </details>

# %%
과일 = ["사과", "귤", "수박"]
for 변수 in 과일:
    print("#####")
# Out:
# #####
# #####
# #####

# %% [markdown]
# ### 133 for문을 풀어서 작성하기

# %% [markdown]
# 다음 for문과 동일한 기능을 수행하는 코드를 for문 없이 작성하세요.
# ```python
# for 변수 in ["A", "B", "C"]:
#     print(변수)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# for문의 동작 원리: 변수 바인딩 → 들여쓰기 코드 실행을 데이터 개수만큼 반복합니다.</br>
# <pre>
# 변수 = "A"
# print(변수)
# 변수 = "B"
# print(변수)
# 변수 = "C"
# print(변수)
#
# # 또는 간단하게:
# print("A")
# print("B")
# print("C")
# </pre>
# </details>

# %%
for 변수 in ["A", "B", "C"]:
    print(변수)
# for문 없이 동일하게 작성해보세요
print("=" * 80)
print("A\nB\nC")
#print("A")
#print("B")
#print("C")
# Out:
# A
# B
# C
# ...
# A
# B
# C

# %% [markdown]
# ### 134 for문을 풀어서 작성하기 (2)

# %% [markdown]
# for문을 풀어서 동일한 동작을 하는 코드를 작성하라.
# ```python
# for 변수 in ["A", "B", "C"]:
#     print("출력:", 변수)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# 변수 = "A"
# print("출력:", 변수)
# 변수 = "B"
# print("출력:", 변수)
# 변수 = "C"
# print("출력:", 변수)
# </pre>
# </details>

# %%
for 변수 in ["A", "B", "C"]:
    print("출력:", 변수)
# for문 없이 동일하게 작성해보세요
print("=" * 80)
print("출력:", "A")
print("출력:", "B")
print("출력:", "C")
# Out:
# 출력: A
# 출력: B
# 출력: C
# ...
# 출력: A
# 출력: B
# 출력: C

# %% [markdown]
# ### 135 for문을 풀어서 작성하기 (3)

# %% [markdown]
# for문을 풀어서 동일한 동작을 하는 코드를 작성하라.
# ```python
# for 변수 in ["A", "B", "C"]:
#     b = 변수.lower()
#     print("변환:", b)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 들여쓰기된 코드 전체를 데이터 개수만큼 반복합니다.</br>
# <pre>
# 변수 = "A"
# b = 변수.lower()
# print("변환:", b)
# 변수 = "B"
# b = 변수.lower()
# print("변환:", b)
# 변수 = "C"
# b = 변수.lower()
# print("변환:", b)
# </pre>
# </details>

# %%
for 변수 in ["A", "B", "C"]:
    b = 변수.lower()
    print("변환:", b)
# for문 없이 동일하게 작성해보세요
print("=" * 80)
변수 = "A"
print("변환:", 변수.lower())
변수 = "B"
print("변환:", 변수.lower())
변수 = "C"
print("변환:", 변수.lower())
# Out:
# 변환: a
# 변환: b
# 변환: c
# ...
# 변환: a
# 변환: b
# 변환: c

# %% [markdown]
# ### 136 코드를 for문으로 변환

# %% [markdown]
# 다음 코드를 for문으로 작성하라.
# ```python
# 변수 = 10
# print(변수)
# 변수 = 20
# print(변수)
# 변수 = 30
# print(변수)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 변하는 값(10, 20, 30)은 리스트로, 변하지 않는 코드(print)는 들여쓰기로 작성합니다.</br>
# <pre>
# for 변수 in [10, 20, 30]:
#     print(변수)
# </pre>
# </details>

# %%
# 아래 코드를 for문으로 변환해보세요
변수 = 10
print(변수)
변수 = 20
print(변수)
변수 = 30
print(변수)
print("=" * 80)
for 변수 in [10, 20, 30]:
  print(변수)
# Out:
# 10
# 20
# 30
# ...
# 10
# 20
# 30

# %% [markdown]
# ### 137 코드를 for문으로 변환 (2)

# %% [markdown]
# 다음 코드를 for문으로 작성하라.
# ```python
# print(10)
# print(20)
# print(30)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# for 변수 in [10, 20, 30]:
#     print(변수)
# </pre>
# </details>

# %%
# 아래 코드를 for문으로 변환해보세요
print(10)
print(20)
print(30)
print("=" * 80)
for nums in [10, 20, 30]:
  print(nums)
# Out:
# 10
# 20
# 30
# ...
# 10
# 20
# 30

# %% [markdown]
# ### 138 코드를 for문으로 변환 (3)

# %% [markdown]
# 다음 코드를 for문으로 작성하라.
# ```python
# print(10)
# print("-------")
# print(20)
# print("-------")
# print(30)
# print("-------")
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 들여쓰기 블록에 두 줄의 코드가 포함됩니다.</br>
# <pre>
# for 변수 in [10, 20, 30]:
#     print(변수)
#     print("-------")
# </pre>
# </details>

# %%
# 아래 코드를 for문으로 변환해보세요
print(10)
print("-------")
print(20)
print("-------")
print(30)
print("-------")
print("=" * 80)
for nums in [10, 20, 30]:
  print(nums)
  print("-------")
# Out:
# 10
# -------
# 20
# -------
# 30
# -------
# ...
# 10
# -------
# 20
# -------
# 30
# -------

# %% [markdown]
# ### 139 for문으로 변환 (반복 외 코드 주의)

# %% [markdown]
# 다음 코드를 for문으로 작성하라.
# ```python
# print("++++")
# print(10)
# print(20)
# print(30)
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <code>print("++++")</code>는 반복되지 않으므로 for문 밖에 작성합니다.</br>
# <pre>
# print("++++")
# for 변수 in [10, 20, 30]:
#     print(변수)
# </pre>
# </details>

# %%
# 아래 코드를 for문으로 변환해보세요
print("++++")
print(10)
print(20)
print(30)

print("=" * 80)

print("++++")
for nums in [10, 20, 30]:
  print(nums)
# Out:
# ++++
# 10
# 20
# 30
# ...
# ++++
# 10
# 20
# 30

# %% [markdown]
# ### 140 for문으로 변환 (변하는 값 없음)

# %% [markdown]
# 다음 코드를 for문으로 작성하라.
# ```python
# print("-------")
# print("-------")
# print("-------")
# print("-------")
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 변하는 값이 없어도, 데이터가 4개인 리스트로 4번 반복할 수 있습니다.</br>
# <pre>
# for 변수 in [1, 2, 3, 4]:
#     print("-------")
#
# # 또는 range 활용:
# for i in range(4):
#     print("-------")
# </pre>
# </details>

# %%
# 아래 코드를 for문으로 변환해보세요
print("-------")
print("-------")
print("-------")
print("-------")
print("=" * 80)
for x in range(4):
  print("-------")
# Out:
# -------
# -------
# -------
# -------
# ...
# -------
# -------
# -------
# -------
