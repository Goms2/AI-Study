# %% [markdown]
# # 파이썬 심화 문제집 - 딕셔너리

# %% [markdown]
# ## 딕셔너리 심화 (301 ~ 310)

# %% [markdown]
# ### 301 딕셔너리 생성 방법

# %% [markdown]
# 다음 세 가지 방법으로 동일한 딕셔너리를 만들어보세요.
# ```
# {'name': '김파이', 'age': 25, 'city': '서울'}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# # 방법 1: 중괄호
# d1 = {'name': '김파이', 'age': 25, 'city': '서울'}
#
# # 방법 2: dict() 함수
# d2 = dict(name='김파이', age=25, city='서울')
#
# # 방법 3: zip으로 생성
# keys = ['name', 'age', 'city']
# values = ['김파이', 25, '서울']
# d3 = dict(zip(keys, values))
#
# print(d1 == d2 == d3)  # True
# </pre>
# </details>

# %%
y = {}
# y['name']= '김파이'
# y['age']= 25
# y['city']= '서울'
# print(y)
y.update({'name': '김파이', 'age': 25, 'city': '서울'})
print(y)
# Out:
# {'name': '김파이', 'age': 25, 'city': '서울'}

# %% [markdown]
# ### 302 get() 메서드 활용

# %% [markdown]
# 아래 딕셔너리에서 'email' 키가 없을 때 기본값 'no email'을 반환하도록 get()을 사용하세요.
# ```python
# user = {'name': '김파이', 'age': 25}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# user = {'name': '김파이', 'age': 25}
#
# # 키가 없을 때 오류 없이 기본값 반환
# email = user.get('email', 'no email')
# print(email)  # no email
#
# name = user.get('name', 'unknown')
# print(name)   # 김파이
# </pre>
# </details>

# %%
user = {'name': '김파이', 'age': 25}
user.get('email', 'no email') # 아래 딕셔너리에서 'email' 키가 없을 때 기본값 'no email'을 반환
# Out:
# 'no email'

# %% [markdown]
# ### 303 setdefault() 메서드

# %% [markdown]
# setdefault()를 사용해서 키가 없을 때만 기본값을 설정하세요.
# ```python
# cart = {'사과': 3}
# # '바나나' 키가 없으면 0으로 초기화 후 2 추가
# # '사과' 키가 이미 있으면 변경하지 않음
# ```
# ```
# 실행 예:
# {'사과': 3, '바나나': 2}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# cart = {'사과': 3}
#
# cart.setdefault('바나나', 0)
# cart['바나나'] += 2
#
# cart.setdefault('사과', 0)  # 이미 있으므로 변경 없음
#
# print(cart)  # {'사과': 3, '바나나': 2}
# </pre>
# </details>

# %%
cart = {'사과': 3}
cart.setdefault("바나나", 0)
cart['바나나'] += 2
cart.setdefault("사과", 0)
print(cart)
# Out:
# {'사과': 3, '바나나': 2}

# %% [markdown]
# ### 304 딕셔너리 병합 (update)

# %% [markdown]
# 두 딕셔너리를 병합하세요. 같은 키가 있으면 d2 값으로 덮어씁니다.
# ```python
# d1 = {'a': 1, 'b': 2}
# d2 = {'b': 99, 'c': 3}
# # 결과: {'a': 1, 'b': 99, 'c': 3}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# d1 = {'a': 1, 'b': 2}
# d2 = {'b': 99, 'c': 3}
#
# # 방법 1: update()
# d1.update(d2)
# print(d1)  # {'a': 1, 'b': 99, 'c': 3}
#
# # 방법 2: ** 언패킹 (원본 유지)
# merged = {**d1, **d2}
# print(merged)
#
# # 방법 3: Python 3.9+
# # merged = d1 | d2
# </pre>
# </details>

# %%
d1 = {'a': 1, 'b': 2}
d2 = {'b': 99, 'c': 3}
d1.update(d2)
print(d1)
p = d1 | d2
print(p)
# Out:
# {'a': 1, 'b': 99, 'c': 3}
# {'a': 1, 'b': 99, 'c': 3}

# %% [markdown]
# ### 305 딕셔너리 컴프리헨션

# %% [markdown]
# 딕셔너리 컴프리헨션을 사용해서 1~5의 제곱수 딕셔너리를 만드세요.
# ```
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# squares = {i: i**2 for i in range(1, 6)}
# print(squares)
# # {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# </pre>
# </details>

# %%
dict = { i : i**2 for i in range(1,6)}
print(dict)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# ### 306 딕셔너리 컴프리헨션 + 조건

# %% [markdown]
# 아래 점수 딕셔너리에서 점수가 70점 이상인 학생만 추출하세요.
# ```python
# scores = {'민수': 85, '지영': 62, '철수': 91, '수연': 55, '태호': 78}
# # 결과: {'민수': 85, '철수': 91, '태호': 78}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# scores = {'민수': 85, '지영': 62, '철수': 91, '수연': 55, '태호': 78}
#
# passed = {name: score for name, score in scores.items() if score >= 70}
# print(passed)  # {'민수': 85, '철수': 91, '태호': 78}
# </pre>
# </details>

# %%
scores = {'민수': 85, '지영': 62, '철수': 91, '수연': 55, '태호': 78}
result = {name: score for name, score in scores.items() if score >= 70}
print(result)
# Out:
# {'민수': 85, '철수': 91, '태호': 78}

# %% [markdown]
# ### 307 딕셔너리 정렬

# %% [markdown]
# 아래 딕셔너리를 값(점수) 기준으로 내림차순 정렬하여 출력하세요.
# ```python
# scores = {'민수': 85, '지영': 62, '철수': 91, '수연': 55, '태호': 78}
# # 결과: 철수 91, 민수 85, 태호 78, 지영 62, 수연 55
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# scores = {'민수': 85, '지영': 62, '철수': 91, '수연': 55, '태호': 78}
#
# sorted_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
# for name, score in sorted_scores:
#     print(name, score)
# </pre>
# </details>

# %%
scores = {'민수': 85, '지영': 62, '철수': 91, '수연': 55, '태호': 78}
sorted_scores = sorted(scores.items(), key=lambda a: a[1], reverse=True)
for name, score in sorted_scores:
    print(name, score)
print(sorted_scores)
sorted_scores = sorted(scores.items())
print(sorted_scores)
# Out:
# 철수 91
# 민수 85
# 태호 78
# 지영 62
# 수연 55
# [('철수', 91), ('민수', 85), ('태호', 78), ('지영', 62), ('수연', 55)]
# [('민수', 85), ('수연', 55), ('지영', 62), ('철수', 91), ('태호', 78)]

# %% [markdown]
# ### 308 단어 빈도수 카운트

# %% [markdown]
# 아래 단어 리스트에서 각 단어의 등장 횟수를 딕셔너리로 만드세요.
# ```python
# words = ['apple', 'banana', 'apple', 'cherry', 'banana', 'apple']
# # 결과: {'apple': 3, 'banana': 2, 'cherry': 1}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# words = ['apple', 'banana', 'apple', 'cherry', 'banana', 'apple']
#
# # 방법 1: 일반 딕셔너리
# count = {}
# for word in words:
#     count[word] = count.get(word, 0) + 1
# print(count)
#
# # 방법 2: collections.Counter
# from collections import Counter
# print(Counter(words))
# </pre>
# </details>

# %%
words = ['apple', 'banana', 'apple', 'cherry', 'banana', 'apple']
from collections import Counter
print(Counter(words))

result = {}
for word in words:
  result[word] = result.get(word, 0) + 1
print(result)
# Out:
# Counter({'apple': 3, 'banana': 2, 'cherry': 1})
# {'apple': 3, 'banana': 2, 'cherry': 1}

# %% [markdown]
# ### 309 중첩 딕셔너리 접근

# %% [markdown]
# 아래 중첩 딕셔너리에서 '민수'의 수학 점수와 '지영'의 영어 점수를 출력하세요.
# ```python
# students = {
#     '민수': {'국어': 85, '수학': 92, '영어': 78},
#     '지영': {'국어': 90, '수학': 65, '영어': 88}
# }
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# students = {
#     '민수': {'국어': 85, '수학': 92, '영어': 78},
#     '지영': {'국어': 90, '수학': 65, '영어': 88}
# }
#
# print(students['민수']['수학'])  # 92
# print(students['지영']['영어'])  # 88
# </pre>
# </details>

# %%
students = {
    '민수': {'국어': 85, '수학': 92, '영어': 78},
    '지영': {'국어': 90, '수학': 65, '영어': 88}
}
print(students['민수']['수학'])
print(students['지영']['영어'])
# Out:
# 92
# 88

# %% [markdown]
# ### 310 딕셔너리 키/값 삭제

# %% [markdown]
# 딕셔너리에서 키를 삭제하는 3가지 방법을 사용해보세요.
# ```python
# d = {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# # 'a'는 del로, 'b'는 pop()으로, 'c'는 popitem()으로 삭제
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# d = {'a': 1, 'b': 2, 'c': 3, 'd': 4}
#
# # 방법 1: del
# del d['a']
#
# # 방법 2: pop() - 삭제된 값 반환
# val = d.pop('b')
# print('삭제된 값:', val)  # 2
#
# # 방법 3: popitem() - 마지막 항목 삭제 및 반환 (Python 3.7+)
# item = d.popitem()
# print('삭제된 항목:', item)
#
# print(d)
# </pre>
# </details>

# %%
d = {'a': 1, 'b': 2, 'c': 3, 'd': 4}
del d['a'] # 삭제
print(d)
b = d.pop('b') # 삭제된값 반환
print()
print('삭제된 값:', b)
print(d)
print()
item = d.popitem() # 마지막 항목 삭제 및 반환
print('삭제된 항목:', item)
print(d)
# Out:
# {'b': 2, 'c': 3, 'd': 4}
#
# 삭제된 값: 2
# {'c': 3, 'd': 4}
#
# 삭제된 항목: ('d', 4)
# {'c': 3}
