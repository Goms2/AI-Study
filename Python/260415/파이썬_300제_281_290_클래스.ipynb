# %% [markdown]
# # 초보자를 위한 파이썬 300제

# %% [markdown]
# ## 11. 파이썬 클래스 (281 ~ 290) - 클래스 상속

# %% [markdown]
# ### 281 차 클래스 정의

# %% [markdown]
# 다음 코드가 동작하도록 차 클래스를 정의하세요.
# ```python
# car = 차(2, 1000)
# print(car.바퀴)   # 2
# print(car.가격)   # 1000
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# class 차:
#     def __init__(self, 바퀴, 가격):
#         self.바퀴 = 바퀴
#         self.가격 = 가격
#
# car = 차(2, 1000)
# print(car.바퀴)
# print(car.가격)
# </pre>
# </details>

# %%
class 차:
  def __init__(self, 바퀴, 가격):
    self.바퀴 = 바퀴
    self.가격 = 가격
car = 차(2, 1000)
print(car.바퀴)   # 2
print(car.가격)   # 1000
# Out:
# 2
# 1000

# %% [markdown]
# ### 282 클래스 상속 기초

# %% [markdown]
# 차 클래스를 상속받은 자전차 클래스를 정의하세요. (내용 없이 상속만)

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# class 자식클래스(부모클래스): 형태로 상속합니다.</br>
# <pre>
# class 차:
#     def __init__(self, 바퀴, 가격):
#         self.바퀴 = 바퀴
#         self.가격 = 가격
#
# class 자전차(차):
#     pass
# </pre>
# </details>

# %%
class 차:
  def __init__(self, 바퀴, 가격):
    self.바퀴 = 바퀴
    self.가격 = 가격
class 자전차(차):
  pass

# %% [markdown]
# ### 283 상속 + 생성자

# %% [markdown]
# 다음 코드가 동작하도록 자전차 클래스를 정의하세요. 단 자전차 클래스는 차 클래스를 상속받습니다.
# ```python
# bicycle = 자전차(2, 100)
# print(bicycle.가격)  # 100
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# class 차:
#     def __init__(self, 바퀴, 가격):
#         self.바퀴 = 바퀴
#         self.가격 = 가격
#
# class 자전차(차):
#     def __init__(self, 바퀴, 가격):
#         self.바퀴 = 바퀴
#         self.가격 = 가격
#
# bicycle = 자전차(2, 100)
# print(bicycle.가격)
# </pre>
# </details>

# %%
class 차:
  def __init__(self, 바퀴, 가격):
    self.바퀴 = 바퀴
    self.가격 = 가격
class 자전차(차):
  def init(self, 바퀴, 가격):
    self.바퀴 = 바퀴
    self.가격 = 가격
bicycle = 자전차(2, 100)
print(bicycle.가격)  # 100
# Out:
# 100

# %% [markdown]
# ### 284 super() - 부모 생성자 호출

# %% [markdown]
# 다음 코드가 동작하도록 자전차 클래스를 정의하세요. 단 자전차 클래스는 차 클래스를 상속받습니다.
# ```python
# bicycle = 자전차(2, 100, "시마노")
# print(bicycle.구동계)  # 시마노
# print(bicycle.바퀴)    # 2
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# super().__init__()으로 부모 클래스의 생성자를 호출합니다.</br>
# <pre>
# class 차:
#     def __init__(self, 바퀴, 가격):
#         self.바퀴 = 바퀴
#         self.가격 = 가격
#
# class 자전차(차):
#     def __init__(self, 바퀴, 가격, 구동계):
#         super().__init__(바퀴, 가격)  # 부모 생성자 호출
#         self.구동계 = 구동계
#
# bicycle = 자전차(2, 100, "시마노")
# print(bicycle.구동계)
# print(bicycle.바퀴)
# </pre>
# </details>

# %%
class 차:
  def __init__(self, 바퀴, 가격):
    self.바퀴 = 바퀴
    self.가격 = 가격
class 자전차(차):
  def __init__(self, 바퀴, 가격, 구동계):
    super().__init__(바퀴, 가격)
    self.구동계 = 구동계

bicycle = 자전차(2, 100, "시마노")
print(bicycle.구동계)  # 시마노
print(bicycle.바퀴)    # 2
# Out:
# 시마노
# 2

# %% [markdown]
# ### 285 상속 + 메서드 추가

# %% [markdown]
# 다음 코드가 동작하도록 차 클래스를 상속받는 자동차 클래스를 정의하세요.
# ```python
# car = 자동차(4, 1000)
# car.정보()
# # 바퀴수  4
# # 가격  1000
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# <pre>
# class 차:
#     def __init__(self, 바퀴, 가격):
#         self.바퀴 = 바퀴
#         self.가격 = 가격
#
# class 자동차(차):
#     def __init__(self, 바퀴, 가격):
#         super().__init__(바퀴, 가격)
#
#     def 정보(self):
#         print("바퀴수 ", self.바퀴)
#         print("가격 ", self.가격)
#
# car = 자동차(4, 1000)
# car.정보()
# </pre>
# </details>

# %%
class 차:
  def __init__(self, 바퀴, 가격):
    self.바퀴 = 바퀴
    self.가격 = 가격
class 자전차(차):
  def __init__(self, 바퀴, 가격, 구동계):
    super().__init__(바퀴, 가격)
    self.구동계 = 구동계
class 자동차(차):
  def __init__(self, 바퀴, 가격):
    super().__init__(바퀴, 가격)
  def 정보(self):
    print("바퀴수 ", self.바퀴)
    print("가격 ", self.가격)
car = 자동차(4, 1000)
car.정보()
# Out:
# 바퀴수  4
# 가격  1000

# %% [markdown]
# ### 286 부모 클래스에 메서드 추가

# %% [markdown]
# 다음 코드가 동작하도록 차 클래스에 정보() 메서드를 추가하세요.
# ```python
# bicycle = 자전차(2, 100, "시마노")
# bicycle.정보()
# # 바퀴수  2
# # 가격  100
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 부모 클래스에 정보() 메서드를 추가하면 자식 클래스도 상속받아 사용할 수 있습니다.</br>
# <pre>
# class 차:
#     def __init__(self, 바퀴, 가격):
#         self.바퀴 = 바퀴
#         self.가격 = 가격
#
#     def 정보(self):
#         print("바퀴수 ", self.바퀴)
#         print("가격 ", self.가격)
#
# class 자전차(차):
#     def __init__(self, 바퀴, 가격, 구동계):
#         super().__init__(바퀴, 가격)
#         self.구동계 = 구동계
#
# bicycle = 자전차(2, 100, "시마노")
# bicycle.정보()
# </pre>
# </details>

# %%
class 차:
  def __init__(self, 바퀴, 가격):
    self.바퀴 = 바퀴
    self.가격 = 가격
  def 정보(self):
    print("바퀴수 ", self.바퀴)
    print("가격 ", self.가격)
class 자전차(차):
  def __init__(self, 바퀴, 가격, 구동계):
    super().__init__(바퀴, 가격)
    self.구동계 = 구동계
class 자동차(차):
  def __init__(self, 바퀴, 가격):
    super().__init__(바퀴, 가격)


bicycle = 자전차(2, 100, "시마노")
bicycle.정보()
# Out:
# 바퀴수  2
# 가격  100

# %% [markdown]
# ### 287 메서드 오버라이딩 + super() 호출

# %% [markdown]
# 자전차의 정보() 메서드로 구동계 정보까지 출력하도록 수정해보세요.
# ```python
# bicycle = 자전차(2, 100, "시마노")
# bicycle.정보()
# # 바퀴수  2
# # 가격  100
# # 구동계  시마노
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# super().정보()로 부모의 정보() 메서드를 먼저 호출한 후 추가 내용을 출력합니다.</br>
# <pre>
# class 자전차(차):
#     def __init__(self, 바퀴, 가격, 구동계):
#         super().__init__(바퀴, 가격)
#         self.구동계 = 구동계
#
#     def 정보(self):
#         super().정보()  # 부모의 정보() 호출
#         print("구동계 ", self.구동계)
#
# bicycle = 자전차(2, 100, "시마노")
# bicycle.정보()
# </pre>
# </details>

# %%
class 차:
  def __init__(self, 바퀴, 가격):
    self.바퀴 = 바퀴
    self.가격 = 가격
  def 정보(self):
    print("바퀴수 ", self.바퀴)
    print("가격 ", self.가격)

class 자전차(차):
  def __init__(self, 바퀴, 가격, 구동계):
    super().__init__(바퀴, 가격)
    self.구동계 = 구동계
  def 정보(self):
    super().정보()
    print("구동계 ", self.구동계)
class 자동차(차):
  def __init__(self, 바퀴, 가격):
    super().__init__(바퀴, 가격)

bicycle = 자전차(2, 100, "시마노")
bicycle.정보()
print('-'*15)
car = 자동차(4, 1000)
car.정보()
# Out:
# 바퀴수  2
# 가격  100
# 구동계  시마노
# ---------------
# 바퀴수  4
# 가격  1000

# %% [markdown]
# ### 288 메서드 오버라이딩 - 결과 예측

# %% [markdown]
# 다음 코드의 실행 결과를 예상해보세요.
# ```python
# class 부모:
#     def 호출(self):
#         print("부모호출")
#
# class 자식(부모):
#     def 호출(self):
#         print("자식호출")
#
# 나 = 자식()
# 나.호출()
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 자식 클래스에서 부모의 메서드를 재정의(오버라이딩)하면 자식 메서드가 호출됩니다.</br>
# <pre>
# # 결과:
# # 자식호출
# </pre>
# </details>

# %%
class 부모:
    def 호출(self):
        print("부모호출")

class 자식(부모):
    def 호출(self):
        print("자식호출")

나 = 자식()
나.호출()
# Out:
# 자식호출

# %% [markdown]
# ### 289 상속 생성자 - 결과 예측

# %% [markdown]
# 다음 코드의 실행 결과를 예상해보세요.
# ```python
# class 부모:
#     def __init__(self):
#         print("부모생성")
#
# class 자식(부모):
#     def __init__(self):
#         print("자식생성")
#
# 나 = 자식()
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# 자식 클래스에 __init__이 있으면 자식의 생성자만 실행됩니다. (부모 생성자는 호출 안 됨)</br>
# <pre>
# # 결과:
# # 자식생성
# </pre>
# </details>

# %%
class 부모:
    def __init__(self):
        print("부모생성")

class 자식(부모):
    def __init__(self):
        print("자식생성")

나 = 자식()
# Out:
# 자식생성

# %% [markdown]
# ### 290 super().__init__() - 결과 예측

# %% [markdown]
# 다음 코드의 실행 결과를 예상해보세요.
# ```python
# class 부모:
#     def __init__(self):
#         print("부모생성")
#
# class 자식(부모):
#     def __init__(self):
#         print("자식생성")
#         super().__init__()
#
# 나 = 자식()
# ```

# %% [markdown]
# <details>
# <summary>여기를 눌러서 정답을 확인하세요 (클릭!)</summary>
# super().__init__()으로 부모 생성자를 명시적으로 호출합니다.</br>
# <pre>
# # 결과:
# # 자식생성
# # 부모생성
# </pre>
# </details>

# %%
class 부모:
    def __init__(self):
        print("부모생성")

class 자식(부모):
    def __init__(self):
        print("자식생성")
        super().__init__()

나 = 자식()
# Out:
# 자식생성
# 부모생성
