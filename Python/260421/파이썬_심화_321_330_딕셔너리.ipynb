# %% [markdown]
# # 파이썬 심화 문제집 - 딕셔너리

# %% [markdown]
# ## 딕셔너리 심화 (321 ~ 330)

# %% [markdown]
# ### 321 CSV → 딕셔너리 리스트

# %% [markdown]
# 아래 CSV 문자열을 딕셔너리 리스트로 변환하세요.
# ```python
# csv_data='name,age,city\n김파이,25,서울\n이파이,30,부산'
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# csv_data='name,age,city\n김파이,25,서울\n이파이,30,부산'
# lines=csv_data.strip().split('\n')
# headers=lines[0].split(',')
# result=[dict(zip(headers,l.split(','))) for l in lines[1:]]
# print(result)
# </pre>
# </details>

# %%
csv_data='name,age,city\n김파이,25,서울\n이파이,30,부산'
lines=csv_data.strip().split('\n')
header=lines[0].split(',')
csv_list=[dict(zip(header, l.split(','))) for l in lines[1:]]
print(csv_list)
# Out:
# [{'name': '김파이', 'age': '25', 'city': '서울'}, {'name': '이파이', 'age': '30', 'city': '부산'}]

# %% [markdown]
# ### 322 딕셔너리 리스트 필터링

# %% [markdown]
# 가격이 10000원 이상인 상품만 추출하세요.
# ```python
# products=[{'name':'사과','price':3000},{'name':'노트북','price':1200000},
#           {'name':'커피','price':5000},{'name':'마우스','price':25000}]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# products=[{'name':'사과','price':3000},{'name':'노트북','price':1200000},
#            {'name':'커피','price':5000},{'name':'마우스','price':25000}]
# for p in [p for p in products if p['price']>=10000]:
#     print(p['name'], f"{p['price']:,}원")
# </pre>
# </details>

# %%
products=[{'name':'사과','price':3000},{'name':'노트북','price':1200000},
          {'name':'커피','price':5000},{'name':'마우스','price':25000}]
for p in [p for p in products if p['price']>= 10000]:
  print(p['name'], f"{p['price']:,}원")
# Out:
# 노트북 1,200,000원
# 마우스 25,000원

# %% [markdown]
# ### 323 딕셔너리 리스트 정렬

# %% [markdown]
# 상품 리스트를 가격 오름차순으로 정렬하세요.
# ```python
# products=[{'name':'사과','price':3000},{'name':'노트북','price':1200000},
#           {'name':'커피','price':5000},{'name':'마우스','price':25000}]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# products=[{'name':'사과','price':3000},{'name':'노트북','price':1200000},
#            {'name':'커피','price':5000},{'name':'마우스','price':25000}]
# for p in sorted(products, key=lambda x:x['price']):
#     print(p['name'], f"{p['price']:,}원")
# </pre>
# </details>

# %%
products=[{'name':'사과','price':3000},{'name':'노트북','price':1200000},
          {'name':'커피','price':5000},{'name':'마우스','price':25000}]
for p in sorted(products, key=lambda x:x['price'], reverse=False):
  print(p['name'], f"{p['price']:,}원")
# Out:
# 사과 3,000원
# 커피 5,000원
# 마우스 25,000원
# 노트북 1,200,000원

# %% [markdown]
# ### 324 딕셔너리 중복 값 제거

# %% [markdown]
# 딕셔너리에서 같은 값을 가진 키 중 먼저 나온 것만 남기세요.
# ```python
# d={'a':1,'b':2,'c':1,'d':3,'e':2}
# # 결과: {'a':1,'b':2,'d':3}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# d={'a':1,'b':2,'c':1,'d':3,'e':2}
# seen=set()
# result={k:v for k,v in d.items() if v not in seen and not seen.add(v)}
# print(result)
# </pre>
# </details>

# %%
d={'a':1,'b':2,'c':1,'d':3,'e':2}
seen=set()
result={k:v for k,v in d.items() if v not in seen and not seen.add(v)}
print(result)
# Out:
# {'a': 1, 'b': 2, 'd': 3}

# %% [markdown]
# ### 325 연락처 관리

# %% [markdown]
# 추가/조회/삭제 함수를 사용한 연락처 관리 프로그램을 작성하세요.

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# contacts={}
# def add(name,phone): contacts[name]=phone; print(f'{name} 추가')
# def find(name): return contacts.get(name,'없음')
# def delete(name):
#     if name in contacts: del contacts[name]; print(f'{name} 삭제')
#     else: print('없음')
# add('김파이','010-1234-5678')
# add('이파이','010-9876-5432')
# print(find('김파이'))
# delete('이파이')
# print(contacts)
# </pre>
# </details>

# %%
contacts={}
def add_number(name, phone):
  contacts[name] = phone
  print(f'{name} 추가')
def search(name):
  result = contacts.get(name, '없음')
  print(result)
  return result

def delete(name):
  if name in contacts:
    del contacts[name]
    print(f'{name} 삭제')
  else:
    print("없음")

add_number('김파이','010-1234-5678')
add_number('이파이','010-9876-5432')
add_number('장동건','010-8888-1705')
search('김파이')
search('원빈')
search('장동건')
delete('이파이')
delete('원빈')
print(contacts)
# Out:
# 김파이 추가
# 이파이 추가
# 장동건 추가
# 010-1234-5678
# 없음
# 010-8888-1705
# 이파이 삭제
# 없음
# {'김파이': '010-1234-5678', '장동건': '010-8888-1705'}

# %% [markdown]
# ### 326 메모이제이션으로 피보나치

# %% [markdown]
# 딕셔너리 캐시로 피보나치를 효율적으로 계산하세요.

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# cache={}
# def fib(n):
#     if n in cache: return cache[n]
#     if n<=1: return n
#     cache[n]=fib(n-1)+fib(n-2)
#     return cache[n]
# for i in range(11):
#     print(f'fib({i})={fib(i)}')
# </pre>
# </details>

# %%
수열={}
def fibonacci(n):
  if 0<=n<=1: return n
  if n>1: return fibonacci(n-1) + fibonacci(n-2)
  return 수열[n]
for i in range(11):
  print(f'fibonacci({i})={fibonacci(i)}')

# cache={}
# def fib(n):
#     if n in cache: return cache[n]
#     if n<=1: return n
#     cache[n]=fib(n-1)+fib(n-2)
#     return cache[n]
# for i in range(11):
#     print(f'fib({i})={fib(i)}')
# Out:
# fibonacci(0)=0
# fibonacci(1)=1
# fibonacci(2)=1
# fibonacci(3)=2
# fibonacci(4)=3
# fibonacci(5)=5
# fibonacci(6)=8
# fibonacci(7)=13
# fibonacci(8)=21
# fibonacci(9)=34
# fibonacci(10)=55

# %% [markdown]
# ### 327 3단계 중첩 딕셔너리

# %% [markdown]
# 지역→학교→학생 3단계 중첩 딕셔너리를 만드세요.
# ```python
# data=[('서울','한강고','민수'),('서울','한강고','지영'),
#       ('서울','남산고','철수'),('부산','해운대고','수연')]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# data=[('서울','한강고','민수'),('서울','한강고','지영'),
#       ('서울','남산고','철수'),('부산','해운대고','수연')]
# result={}
# for city,school,student in data:
#     result.setdefault(city,{}).setdefault(school,[]).append(student)
# for city,schools in result.items():
#     for school,students in schools.items():
#         print(f'{city}>{school}:{students}')
# </pre>
# </details>

# %%
data=[('서울','한강고','민수'),('서울','한강고','지영'),
      ('서울','남산고','철수'),('부산','해운대고','수연')]
결과 = {}
for city, school, student in data:
  결과.setdefault(city, {}).setdefault(school, []).append(student)
  for city, schools in 결과.items():
    for school, students in schools.items():
      print(f'{city}>{school}:{students}')
# Out:
# 서울>한강고:['민수']
# 서울>한강고:['민수', '지영']
# 서울>한강고:['민수', '지영']
# 서울>남산고:['철수']
# 서울>한강고:['민수', '지영']
# 서울>남산고:['철수']
# 부산>해운대고:['수연']

# %% [markdown]
# ### 328 중첩 딕셔너리 flatten

# %% [markdown]
# 중첩 딕셔너리를 1단계로 펼치세요.
# ```python
# nested={'민수':{'국어':85,'수학':92},'지영':{'국어':90,'수학':65}}
# # 결과: {'민수_국어':85,'민수_수학':92,...}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# nested={'민수':{'국어':85,'수학':92},'지영':{'국어':90,'수학':65}}
# flat={f'{o}_{i}':v for o,d in nested.items() for i,v in d.items()}
# print(flat)
# </pre>
# </details>

# %%
nested={'민수':{'국어':85,'수학':92},'지영':{'국어':90,'수학':65}}
flatten={f'{o}_{i}':v for o,d in nested.items() for i,v in d.items()}
print(flatten)
# Out:
# {'민수_국어': 85, '민수_수학': 92, '지영_국어': 90, '지영_수학': 65}

# %% [markdown]
# ### 329 키 존재 확인 방법 비교

# %% [markdown]
# 딕셔너리에서 키 존재 여부를 확인하는 3가지 방법을 사용해보세요.
# ```python
# d={'name':'김파이','age':25}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# d={'name':'김파이','age':25}
# print('name' in d)          # True  - in 연산자
# print(d.get('email','없음')) # 없음  - get() 활용
# print('email' in d.keys())  # False - keys()
# </pre>
# </details>

# %%
d={'name':'김파이','age':25}
print('name' in d)
print(d.get('age','없음'))
print('height' in d.keys())
# Out:
# True
# 25
# False

# %% [markdown]
# ### 330 딕셔너리 순회 4가지

# %% [markdown]
# 딕셔너리를 순회하는 4가지 방법을 모두 사용하세요.
# ```python
# scores={'민수':85,'지영':62,'철수':91}
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# scores={'민수':85,'지영':62,'철수':91}
# print('--- 키만 ---')
# for k in scores: print(k)
# print('--- 값만 ---')
# for v in scores.values(): print(v)
# print('--- 키+값 ---')
# for k,v in scores.items(): print(k,v)
# print('--- enumerate ---')
# for i,(k,v) in enumerate(scores.items()): print(i,k,v)
# </pre>
# </details>

# %%
scores={'민수':85,'지영':62,'철수':91}

for k in scores:
  print(k)
print('-'*10)
for v in scores.values():
  print(v)
print('-'*10)
for k,v in scores.items():
  print(k,v)
print('-'*10)
for i,(k,v) in enumerate(scores.items()):
  print(i,k,v)
# Out:
# 민수
# 지영
# 철수
# ----------
# 85
# 62
# 91
# ----------
# 민수 85
# 지영 62
# 철수 91
# ----------
# 0 민수 85
# 1 지영 62
# 2 철수 91
