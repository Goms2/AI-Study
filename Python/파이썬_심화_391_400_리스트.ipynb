# %% [markdown]
# # 파이썬 심화 문제집 - 리스트

# %% [markdown]
# ## 리스트 심화 (391 ~ 400)

# %% [markdown]
# ### 391 리스트 - 상품 재고 관리

# %% [markdown]
# 상품 리스트에서 재고 관리(입고/출고/조회)를 딕셔너리와 리스트로 구현하세요.

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# inventory={}
# def stock_in(item,qty):
#     inventory[item]=inventory.get(item,0)+qty
#     print(f'{item} {qty}개 입고 (재고:{inventory[item]})')
# def stock_out(item,qty):
#     if inventory.get(item,0)>=qty:
#         inventory[item]-=qty
#         print(f'{item} {qty}개 출고 (재고:{inventory[item]})')
#     else:
#         print('재고 부족!')
# def check(): print(inventory)
#
# stock_in('사과',100)
# stock_in('배',50)
# stock_out('사과',30)
# check()
# </pre>
# </details>

# %%
inven={}
def stock_in(item,qty):
  inven[item]=inven.get(item,0)+qty
  print(f'{item} : {qty}개 입고 (재고: {inven[item]})')
def stock_out(item, qty):
  current_stock = inven.get(item, 0) # 현재 재고 확인

  if current_stock >= qty:
      # 재고가 충분할 때
      inven[item] -= qty
      print(f'{item} : {qty}개 출고 (재고: {inven[item]})')
  else:
      # 재고가 부족할 때 (남아있는 수량만큼만 출고)
      actual_out = current_stock # 실제 나갈 수 있는 양은 현재 재고 전부
      inven[item] = 0            # 재고는 0으로 변경
      print(f'{item} : {actual_out}개 출고 [재고부족으로 {actual_out}개만 나감] (재고:{ inven[item]})')

def check():
  print(inven)

stock_in('사과',100)
stock_in('배',50)
stock_out('사과',30)
stock_out('사과',100)
check()
# Out:
# 사과 : 100개 입고 (재고: 100)
# 배 : 50개 입고 (재고: 50)
# 사과 : 30개 출고 (재고: 70)
# 사과 : 70개 출고 [재고부족으로 70개만 나감] (재고:0)
# {'사과': 0, '배': 50}

# %% [markdown]
# ### 392 리스트 - 학생 석차 계산

# %% [markdown]
# 점수 리스트를 받아 각 학생의 석차(같은 점수면 동일 석차)를 반환하세요.
# ```python
# scores=[90,85,90,80,85]
# # 결과: [1,3,1,5,3]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# scores=[90,85,90,80,85]
# ranks=[]
# for s in scores:
#     rank=sum(1 for x in scores if x>s)+1
#     ranks.append(rank)
# print(ranks)
# </pre>
# </details>

# %%
scores=[90,85,90,80,85]
ranks=[]
for s in scores:
    ranks = [sum(1 for x in scores if x > s) + 1 for s in scores]
print(ranks)
# Out:
# [1, 3, 1, 5, 3]

# %% [markdown]
# ### 393 리스트 - 달팽이 배열

# %% [markdown]
# n×n 달팽이 배열을 만드세요.
# ```python
# # n=3:
# # [[1,2,3],
# #  [8,9,4],
# #  [7,6,5]]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# def snail(n):
#     matrix=[[0]*n for _ in range(n)]
#     top,bottom,left,right=0,n-1,0,n-1
#     num=1
#     while top<=bottom and left<=right:
#         for i in range(left,right+1): matrix[top][i]=num; num+=1
#         top+=1
#         for i in range(top,bottom+1): matrix[i][right]=num; num+=1
#         right-=1
#         for i in range(right,left-1,-1): matrix[bottom][i]=num; num+=1
#         bottom-=1
#         for i in range(bottom,top-1,-1): matrix[i][left]=num; num+=1
#         left+=1
#     return matrix
# for row in snail(3): print(row)
# </pre>
# </details>

# %%
def snail(n):
    matrix=[[0]*n for _ in range(n)]
    top,bottom,left,right=0,n-1,0,n-1
    num=1
    while top<=bottom and left<=right:
        for i in range(left,right+1): matrix[top][i]=num; num+=1
        top+=1
        for i in range(top,bottom+1): matrix[i][right]=num; num+=1
        right-=1
        for i in range(right,left-1,-1): matrix[bottom][i]=num; num+=1
        bottom-=1
        for i in range(bottom,top-1,-1): matrix[i][left]=num; num+=1
        left+=1
    return matrix
for row in snail(3): print(row)
# Out:
# [1, 2, 3]
# [8, 9, 4]
# [7, 6, 5]

# %% [markdown]
# ### 394 리스트 - 배열 회전

# %% [markdown]
# 2차원 배열을 시계방향 90도 회전시키세요.
# ```python
# matrix=[[1,2,3],[4,5,6],[7,8,9]]
# # 결과: [[7,4,1],[8,5,2],[9,6,3]]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# matrix=[[1,2,3],[4,5,6],[7,8,9]]
# rotated=list(zip(*matrix[::-1]))
# for row in rotated: print(list(row))
# </pre>
# </details>

# %%
matrix=[[1,2,3],[4,5,6],[7,8,9]]
rotated=list(zip(*matrix[::-1]))
for row in rotated:
  print(list(row))
# Out:
# [7, 4, 1]
# [8, 5, 2]
# [9, 6, 3]

# %% [markdown]
# ### 395 리스트 - 두 배열의 중앙값

# %% [markdown]
# 두 정렬된 배열을 합쳤을 때의 중앙값을 구하세요.
# ```python
# a=[1,3,5]; b=[2,4,6]
# # 합치면 [1,2,3,4,5,6] → 중앙값 (3+4)/2 = 3.5
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# a=[1,3,5]; b=[2,4,6]
# merged=sorted(a+b)
# n=len(merged)
# if n%2: print(merged[n//2])
# else: print((merged[n//2-1]+merged[n//2])/2)
# </pre>
# </details>

# %%
a=[1,3,5]; b=[2,4,6]
merged=sorted(a+b)
n=len(merged)
if n%2:
  print(merged[n//2])
else:
  print((merged[n//2-1]+merged[n//2])/2)
# Out:
# 3.5

# %% [markdown]
# ### 396 리스트 - 구간 합산 업데이트

# %% [markdown]
# 리스트에 구간 [l,r]에 일정값을 더하는 연산을 효율적으로 구현하세요.
# ```python
# nums=[0,0,0,0,0]
# # add(1,3,10) → [0,10,10,10,0]
# # add(2,4,5) → [0,10,15,15,5]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# nums=[0]*5
# def add(l,r,val):
#     for i in range(l,r+1): nums[i]+=val
# add(1,3,10)
# print(nums)
# add(2,4,5)
# print(nums)
# </pre>
# </details>

# %%
nums=[0,0,0,0,0]
def add(l,r,val):
    for i in range(l,r+1):
      nums[i]+=val
add(1,3,10)
print(nums)
add(2,4,5)
print(nums)
# Out:
# [0, 10, 10, 10, 0]
# [0, 10, 15, 15, 5]

# %% [markdown]
# ### 397 리스트 - 특정 합이 되는 연속 부분 배열

# %% [markdown]
# 합이 target이 되는 연속 부분 배열의 개수를 구하세요.
# ```python
# nums=[1,1,1]; target=2
# # 결과: 2
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# from collections import defaultdict
# nums=[1,1,1]; target=2
# count=0; prefix=0
# freq=defaultdict(int); freq[0]=1
# for n in nums:
#     prefix+=n
#     count+=freq[prefix-target]
#     freq[prefix]+=1
# print(count)
# </pre>
# </details>

# %%
from collections import defaultdict
nums=[1,1,1]
target=2
count=0
prefix=0
freq=defaultdict(int)
freq[0]=1
for n in nums:
    prefix+=n
    count+=freq[prefix-target]
    freq[prefix]+=1
print(count)
# Out:
# 2

# %% [markdown]
# ### 398 리스트 - 좌표 압축

# %% [markdown]
# 좌표 리스트를 상대적 순위로 압축하세요.
# ```python
# coords=[100,10000,1,500,70]
# # 결과: [1,3,0,2, ... 처럼 0부터 시작하는 순위]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# coords=[100,10000,1,500,70]
# sorted_unique=sorted(set(coords))
# rank={v:i for i,v in enumerate(sorted_unique)}
# print([rank[c] for c in coords])
# </pre>
# </details>

# %%
coords=[100,10000,1,500,70]
sorted_unique=sorted(set(coords))
print(sorted_unique)
rank={v:i for i,v in enumerate(sorted_unique)}
print(rank)
print([rank[c] for c in coords])
# Out:
# [1, 70, 100, 500, 10000]
# {1: 0, 70: 1, 100: 2, 500: 3, 10000: 4}
# [2, 4, 0, 3, 1]

# %% [markdown]
# ### 399 리스트 - 행렬 나선형 출력

# %% [markdown]
# 2차원 행렬을 나선형 순서로 1차원 리스트로 출력하세요.
# ```python
# matrix=[[1,2,3],[4,5,6],[7,8,9]]
# # 결과: [1,2,3,6,9,8,7,4,5]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# def spiral(matrix):
#     result=[]
#     while matrix:
#         result+=matrix.pop(0)
#         matrix=[list(x) for x in zip(*matrix)][::-1]
#     return result
# print(spiral([[1,2,3],[4,5,6],[7,8,9]]))
# </pre>
# </details>

# %%
matrix=[[1,2,3],[4,5,6],[7,8,9]]
def spiral(matrix):
    result=[]
    while matrix:
        result+=matrix.pop(0)
        matrix=[list(x) for x in zip(*matrix)][::-1]
    return result
print(spiral(matrix))
# Out:
# [1, 2, 3, 6, 9, 8, 7, 4, 5]

# %% [markdown]
# ### 400 리스트 종합 문제 - 데이터 분석

# %% [markdown]
# 주식 데이터 리스트에서 평균, 최고가, 최저가, 변동폭을 한 번에 계산하세요.
# ```python
# prices=[75000,76500,74000,77000,75500,78000,73000]
# ```

# %% [markdown]
# <details>
# <summary>정답 확인 (클릭!)</summary>
# <pre>
# prices=[75000,76500,74000,77000,75500,78000,73000]
# print(f'평균: {sum(prices)/len(prices):,.0f}원')
# print(f'최고: {max(prices):,}원')
# print(f'최저: {min(prices):,}원')
# print(f'변동폭: {max(prices)-min(prices):,}원')
# returns=[(prices[i]-prices[i-1])/prices[i-1]*100 for i in range(1,len(prices))]
# print(f'평균 수익률: {sum(returns)/len(returns):.2f}%')
# </pre>
# </details>

# %%
prices=[75000,76500,74000,77000,75500,78000,73000]
def get_avg(n):
  print(f'평균: {sum(n)/len(n):,.0f}원')
def get_max(n):
  print(f'최고: {max(n):,}원')
def get_min(n):
  print(f'최저: {min(prices):,}원')
def get_range(n):
    diff = max(n) - min(n)
    print(f'변동폭: {diff:,}원')
def get_returns(n):
    returns=[(prices[i]-prices[i-1])/prices[i-1]*100 for i in range(1,len(prices))]
    print(f'평균 수익률: {sum(returns)/len(returns):.2f}%')
get_avg(prices)
get_max(prices)
get_min(prices)
get_range(prices)
get_returns(prices)
# Out:
# 평균: 75,571원
# 최고: 78,000원
# 최저: 73,000원
# 변동폭: 5,000원
# 평균 수익률: -0.38%
